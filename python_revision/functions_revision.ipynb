# %%
# simple function
def myFunc():
    print("Hello")

myFunc()
# Out:
# Hello

# %%
# function with return
def func_return():
    x = "Hello"
    return x

print(func_return() , "Mohamed")
# Out:
# Hello Mohamed

# %%
# function with arguments
def func2(fname):
    return fname + "Mohamed"

print(func2("Hello "))
# Out:
# Hello Mohamed

# %%
# *args function
def func3(*args):
    print("Type", type(args))
    print("First Argument:", args[0])
    print("Second Argument:", args[1])
    print("All arguments:", args)

func3("Mohamed","Nada","Celine","Malek")
# Out:
# Type <class 'tuple'>
# First Argument: Mohamed
# Second Argument: Nada
# All arguments: ('Mohamed', 'Nada', 'Celine', 'Malek')

# %%
# Functions in Python has metadata that can be accessed using the __name__ and __doc__ attributes.
def func3():
    return __name__
print(func3())
print(func3.__name__)
if __name__ == '__main__':
    print("Hello")
# Out:
# __main__
# func3
# Hello

# %%
# Lambda function
x = lambda a : a * 10
print(x(5))
# Out:
# 50

# %%
# another lambda function example
x = lambda a,b,c: a+b+c
print(x(1,2,3))
# Out:
# 6

# %%
# Lambda with built in functions
# 1- The map() function applies a function to every item in an iterable:
numbers = [1,2,3,4]
doubled = list(map(lambda x : x * 2 , numbers))
print(doubled)
# Out:
# [2, 4, 6, 8]

# %%
# The filter() function creates a list of items for which a function returns True:
numbers = [2,5,8,6,9]
odd_numbers = list(filter(lambda x : x%2 != 0 , numbers))
print(odd_numbers)
# Out:
# [5, 9]

# %%
# The sorted() function can use a lambda as a key for custom sorting:
# example: Sort a list of tuples by the second element:
students = [("Emil",25),("Tobias",22),("Linus",28)]
sorted_students = sorted(students , key = lambda x : x[1])
print(sorted_students)
# Out:
# [('Tobias', 22), ('Emil', 25), ('Linus', 28)]

# %% [markdown]
# **Helper Functions**
# > A helper function is a small, focused function that performs a specific subtask to support a larger, more complex function. It's not meant to be the main logic — it helps other functions do their job.

# %%
# ── Helper Functions ──────────────────────────────────────────
def add(a, b):
    """Returns the sum of a and b."""
    return a + b

def subtract(a, b):
    """Returns the difference of a and b."""
    return a - b

def multiply(a, b):
    """Returns the product of a and b."""
    return a * b

def divide(a, b):
    """Returns the division of a by b."""
    if b == 0:
        raise ValueError("Cannot divide by zero.")
    return a / b

def power(base, exp):
    """Returns base raised to the power of exp."""
    return base ** exp

def average(numbers):
    """Returns the average of a list of numbers."""
    if not numbers:
        raise ValueError("List cannot be empty.")
    return sum(numbers) / len(numbers)


# ── Main Function (uses helpers) ──────────────────────────────
def summarize(a, b):
    print(f"Numbers     : {a}, {b}")
    print(f"Add         : {add(a, b)}")
    print(f"Subtract    : {subtract(a, b)}")
    print(f"Multiply    : {multiply(a, b)}")
    print(f"Divide      : {divide(a, b)}")
    print(f"Power (a^b) : {power(a, b)}")
    print(f"Average     : {average([a, b])}")


# ── Run ───────────────────────────────────────────────────────
summarize(10, 2)
# Out:
# Numbers     : 10, 2
# Add         : 12
# Subtract    : 8
# Multiply    : 20
# Divide      : 5.0
# Power (a^b) : 100
# Average     : 6.0
