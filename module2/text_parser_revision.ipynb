# %%
import os
from pathlib import Path
path = Path('documentation.md')

print(path.name)  # File name
print(str(path.absolute()))  # Full path
print(path.stat().st_size)  # File size
print(path.suffix)   # File extention
# Out:
# documentation.md
# d:\programming\VS-Code_Workspace\RAG-Course\module2\documentation.md
# 5168
# .md

# %%
with open('documentation.md','r') as f:
    content = f.read()

print("Char count:", len(content))
print("Word Count:", len(content.split()))
# Out:
# Char count: 5038
# Word Count: 692
